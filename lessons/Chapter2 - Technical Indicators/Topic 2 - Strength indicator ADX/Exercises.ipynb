# %% [markdown]
# # Exercises — Strength indicator: ADX
#
# [DataCamp exercise](https://campus.datacamp.com/courses/financial-trading-in-python/technical-indicators?ex=4) · see `Notes.md` in this folder for the summary.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# Locate the project's data folder regardless of where this notebook runs from
DATA = next(p / "course materials" / "data"
            for p in [Path.cwd(), *Path.cwd().parents]
            if (p / "course materials" / "data").is_dir())

def load(name):
    """Load an OHLCV CSV with a parsed DatetimeIndex."""
    return pd.read_csv(DATA / name, index_col="Date", parse_dates=True)

def price(name, col, year=None):
    """Single-asset price DataFrame (column = `col`) for use with bt."""
    df = load(name)
    if year:
        df = df[df.index.year == year]
    return df["Close"].rename(col).to_frame()

# %%
import talib

amzn = load("AMZN-stock-data.csv")
amzn = amzn[amzn.index.year == 2020]
amzn["ADX"] = talib.ADX(amzn["High"], amzn["Low"], amzn["Close"], timeperiod=14)
print(amzn[["Close", "ADX"]].tail())

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(9, 6), sharex=True)
ax1.plot(amzn.index, amzn["Close"]); ax1.set_title("AMZN price")
ax2.plot(amzn.index, amzn["ADX"], color="purple")
ax2.axhline(25, color="red", ls="--")          # trend threshold
ax2.set_title("ADX (14)"); ax2.set_ylim(0, 100)
plt.show()

# %% [markdown]
# ---
#
# ## Coding exercises in this section
#
# The `script.py` starter for each Coding exercise under the **Strength indicator: ADX** video (course exercises 6, 7). Blanks (`____`) are as shown in DataCamp — fill them in to solve.

# %% [markdown]
# ### 6. Calculate the ADX
#
# Calculate the ADX using the appropriate function from `talib` and the `High`, `Low`, and `Close` columns in `stock_data`; save it in `ADX_14`. Calculate it again with a time period of 21 and store it in `ADX_21`. Print the last five rows.
#
# **Instructions** — see the description above.

# %%
# Calculate the ADX with the default time period
stock_data['ADX_14'] = ____(stock_data['____'],
                            stock_data['____'], 
                            stock_data['____'])

# Calculate the ADX with the time period set to 21
stock_data['ADX_21'] = ____

# Print the last five rows
print(stock_data.____())

# %% [markdown]
# ### 7. Visualize the ADX
#
# The ADX quantifies the strength of a trend but not its direction; an ADX value above 25 typically indicates a trending market. Calculate the ADX and plot it alongside the price on separate subplots.
#
# **Instructions** — see the description above.

# %%
# Calculate ADX
stock_data['ADX'] = ____(stock_data['____'], stock_data['____'], stock_data['____'])

# Create subplots
fig, (ax1, ax2) = ____(2)

# Plot ADX with the price
ax1.set_ylabel('Price')
____(stock_data['____'])
ax2.set_ylabel('ADX')
____(stock_data['____'], color='red')

ax1.set_title('Price and ADX')
plt.show()
