# %% [markdown]
# # Exercises — Financial trading with bt
#
# [DataCamp exercise](https://campus.datacamp.com/courses/financial-trading-in-python/trading-basics-1?ex=9) · see `Notes.md` in this folder for the summary.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# Locate the project's data folder regardless of where this notebook runs from
DATA = next(p / "course materials" / "data"
            for p in [Path.cwd(), *Path.cwd().parents]
            if (p / "course materials" / "data").is_dir())

def load(name):
    """Load an OHLCV CSV with a parsed DatetimeIndex."""
    return pd.read_csv(DATA / name, index_col="Date", parse_dates=True)

def price(name, col, year=None):
    """Single-asset price DataFrame (column = `col`) for use with bt."""
    df = load(name)
    if year:
        df = df[df.index.year == year]
    return df["Close"].rename(col).to_frame()

# %% [markdown]
# ### The 4-step bt process: get data, define strategy, backtest, evaluate

# %%
import bt

# 1. Get data (equal-weight portfolio of three stocks, 2020 H1)
data = pd.DataFrame({
    "GOOG": load("GOOG-stock-data.csv")["Close"],
    "AMZN": load("AMZN-stock-data.csv")["Close"],
    "TSLA": load("TSLA-stock-data.csv")["Close"],
}).dropna()
data = data[(data.index.year == 2020) & (data.index <= "2020-06-30")]

# 2. Define the strategy from algos
bt_strategy = bt.Strategy("Trade_Weekly", [
    bt.algos.RunWeekly(),
    bt.algos.SelectAll(),
    bt.algos.WeighEqually(),
    bt.algos.Rebalance(),
])

# 3. Backtest
bt_result = bt.run(bt.Backtest(bt_strategy, data))

# 4. Evaluate
bt_result.plot(title="Backtest result")
plt.show()
bt_result.display()
# Out:
# Stat                 Trade_Weekly
# -------------------  --------------
# Start                2020-01-01
# End                  2020-06-30
# Risk-free rate       0.00%
#
# Total Return         60.70%
# Daily Sharpe         2.11
# Daily Sortino        3.00
# CAGR                 160.46%
# Max Drawdown         -37.04%
# Calmar Ratio         4.33
#
# MTD                  13.25%
# 3m                   56.15%
# 6m                   -
# YTD                  60.70%
# 1Y                   -
# 3Y (ann.)            -
# 5Y (ann.)            -
# 10Y (ann.)           -
# Since Incep. (ann.)  160.46%
#
# Daily Sharpe         2.11
# Daily Sortino        3.00
# Daily Mean (ann.)    109.29%
# Daily Vol (ann.)     51.81%
# Daily Skew           -0.66
# Daily Kurt           1.93
# Best Day             8.53%
# Worst Day            -11.45%
#
# Monthly Sharpe       1.54
# Monthly Sortino      5.17
# Monthly Mean (ann.)  84.19%
# Monthly Vol (ann.)   54.64%
# Monthly Skew         0.79
# ...

# %% [markdown]
# ---
#
# ## Coding exercises in this section
#
# The `script.py` starter for each Coding exercise under the **Financial trading with bt** video (course exercises 10, 11). Blanks (`____`) are as shown in DataCamp — fill them in to solve.
#
# > Some of these are multi-step exercises whose exact `script.py` could not be reliably pulled from the course page; those code cells are placeholders to paste the editor code into.

# %% [markdown]
# ### 10. The bt process
#
# Walk through the `bt` process end to end: get the data, define a strategy from algos, run the backtest, and evaluate the result.
#
# **Instructions** — see the description above.

# %%
# The verbatim script.py for this multi-step exercise could not be reliably
# retrieved from the course page. Paste the starter code from the DataCamp
# editor for exercise 10 ("The bt process") here.

# %% [markdown]
# ### 11. Define and backtest a simple strategy
#
# Work with FAANG stock data (`bt_data`): inspect the data, define a strategy that holds an equal weight of each stock and rebalances every week, then run the backtest and plot the result. The `bt` package is pre-imported.
#
# **Instructions** — see the description above.

# %%
# The verbatim script.py for this multi-step exercise could not be reliably
# retrieved from the course page. Paste the starter code from the DataCamp
# editor for exercise 11 ("Define and backtest a simple strategy") here.
# Print the top five rows
print(data.head())

# Define the strategy
bt_strategy = bt.Strategy('Trade_Weekly',
                         [bt.algos.RunWeekly(),
                          bt.algos.SelectAll(),
                          bt.algos.WeighEqually(),
                          bt.algos.Rebalance()])

# Create a backtest
bt_test = bt.Backtest(bt_strategy, data)
# Run the backtest
bt_res = bt.run(bt_test)

# Plot the test result
bt_res.plot(title="Backtest result")
plt.show()
# Out:
#                GOOG     AMZN   TSLA
# Date
# 2020-01-02  1367.37  1898.01  86.05
# 2020-01-03  1360.66  1874.97  88.60
# 2020-01-06  1394.21  1902.88  90.31
# 2020-01-07  1393.34  1906.86  93.81
# 2020-01-08  1404.32  1891.97  98.43
